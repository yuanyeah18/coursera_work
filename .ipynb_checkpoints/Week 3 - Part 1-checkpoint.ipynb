# %% [markdown]
# # Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
#  download all the dependencies that we will need.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
bsObj = BeautifulSoup(html, "html.parser")
#The main comparison table is currently the first table on the page
table = bsObj.findAll("table",{"class":"wikitable"})[0]
#就本例使用bs4分析来说， 其实得到的是bs4.element.ResultSet 
#从字面翻译，可理解成bs4的结果集，不过应该是一个列表， 而要提取里面的内容，就加上[0]
#此时从bs4的角度来说，得到了一个bs4.element.Tag ， 从列表的内容提取来
#说得到了列表里第一个元素的内容。
# print(table)
rows = table.findAll("tr")
# print(rows) 这一行是得到表格中所有按行的内容

csvFile = open("tt.csv", 'wt', newline='', encoding='utf-8')
#当开始写入csv的时候，是按行写的，包含了表格头的内容
writer = csv.writer(csvFile)
try:
    for row in rows:
        csvRow = []
        for cell in row.findAll(['td']):
            csvRow.append(cell.get_text())
        writer.writerow(csvRow)
finally:
    csvFile.close()

# %%
df = pd.read_csv("tt.csv")
print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!
#   Postcode           Borough       Neighbourhood
# 0      M2A      Not assigned      Not assigned\n
# 1      M3A        North York         Parkwoods\n
# 2      M4A        North York  Victoria Village\n
# 3      M5A  Downtown Toronto      Harbourfront\n
# 4      M5A  Downtown Toronto       Regent Park\n

# %% [markdown]
# give columns name

# %%
# 如果需要改列名称 用 
df.columns = ['Postcode', 'Borough', 'Neighbourhood'] 
df.dtypes

# %% [markdown]
# file is a dataframe, and dtypes is an attribute
# df.dtypes （显示 每一个serious 的datatype）
#
# When you access dtypes, a Series is returned:
# type(df.dtypes)  ----- pandas.core.series.Series
#
# When you call df.dtypes(), you are effectively doing series = df.dtype; series() which is invalid, since series is an object (not a function, or an object with __call__ defined).

# %% [markdown]
# clean data if the value is Not assigned

# %%
df=df.replace(['Not assigned','Not assigned\n'],np.nan)
df= df.dropna(axis = 0,how='any')
df
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# 30       M3K        North York
# 31       M3L        North York
# 32       M3M        North York
# 33       M3N        North York
# 34       M4A        North York
# 35       M4B         East York
# 36       M4C         East York
# 37       M4E      East Toronto
# 38       M4G         East York
# 39       M4H         East York
# 40       M4J         East York
# 41       M4K      East Toronto
# 42       M4L      East Toronto
# 43       M4M      East Toronto
# 44       M4N   Central Toronto
# 45       M4P   Central Toronto
# 46       M4R   Central Toronto
# 47       M4S   Central Toronto
# 48       M4T   Central Toronto
# 49       M4V   Central Toronto
# 50       M4W  Downtown Toronto
# 51       M4X  Downtown Toronto
# 52       M4Y  Downtown Toronto
# 53       M5A  Downtown Toronto
# 54       M5B  Downtown Toronto
# 55       M5C  Downtown Toronto
# 56       M5E  Downtown Toronto
# 57       M5G  Downtown Toronto
# 58       M5H  Downtown Toronto
# 59       M5J  Downtown Toronto
# 60       M5K  Downtown Toronto
# 61       M5L  Downtown Toronto
# 62       M5M        North York
# 63       M5N   Central Toronto
# 64       M5P   Central Toronto
# 65       M5R   Central Toronto
# 66       M5S  Downtown Toronto
# 67       M5T  Downtown Toronto
# 68       M5V  Downtown Toronto
# 69       M5W  Downtown Toronto
# 70       M5X  Downtown Toronto
# 71       M6A        North York
# 72       M6B        North York
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7R       Mississauga
# 86       M7Y      East Toronto
# 87       M8V         Etobicoke
# 88       M8W         Etobicoke
# 89       M8X         Etobicoke
# 90       M8Y         Etobicoke
# 91       M8Z         Etobicoke
# 92       M9A         Etobicoke
# 93       M9B         Etobicoke
# 94       M9C         Etobicoke
# 95       M9L        North York
# 96       M9M        North York
# 97       M9N              York
# 98       M9P         Etobicoke
# 99       M9R         Etobicoke
# 100      M9V         Etobicoke
# 101      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                   Rouge\n, Malvern\n
# 1    Highland Creek\n,     Rouge Hill\n,     Port U...
# 2            Guildwood\n, Morningside\n,   West Hill\n
# 3                                             Woburn\n
# 4                                          Cedarbrae\n
# 5                                Scarborough Village\n
# 6    East Birchmount Park\n,              Ionview\n...
# 7             Clairlea\n, Golden Mile\n,    Oakridge\n
# 8    Cliffcrest\n,                Cliffside\n, Scar...
# 9                      Birch Cliff\n, Cliffside West\n
# 10   Dorset Park\n, Scarborough Town Centre\n,     ...
# 11                              Maryvale\n,  Wexford\n
# 12                                         Agincourt\n
# 13   Clarks Corners\n,       Sullivan\n,  Tam O'Sha...
# 14   Agincourt North\n, L'Amoreaux East\n,        M...
# 15                L'Amoreaux West\n,    Steeles West\n
# 16                                       Upper Rouge\n
# 91   Kingsway Park South West\n,                Mim...
# 92                                  Islington Avenue\n
# 93   Cloverdale\n,        Islington\n,     Martin G...
# 94   Bloordale Gardens\n,          Eringate\n,     ...
# 95                                     Humber Summit\n
# 96                                Emery\n, Humberlea\n
# 97                                            Weston\n
# 98                                         Westmount\n
# 99   Kingsview Village\n, Martin Grove Gardens\n,  ...
# 100  Albion Gardens\n, Beaumond Heights\n,       Hu...
# 101                                        Northwest\n

# %% [markdown]
# <span style="color:red"> ** those codes can't work. can someone help me explain why** </span>
# --------------
# df[df.Neighbourhood != 'Not assigned\n']
# df["Neighbourhood"].replace('Not assigned',np.nan)
# df.dropna(subset=[Neighbourhood], axis=0, inplace = True)

# %% [markdown]
# # you can also use this to drop

# %%
# # Drop a row by condition
# df= df.where(df !="Not assigned\n").dropna(axis = 0)
# df= df[df.Borough != 'Not assigned']
# df

# %%
#df = df.groupby(['Postcode', 'Borough']).agg({'Neighbourhood':','.join}).reset_index()

df = df.groupby(['Postcode', 'Borough'])['Neighbourhood'].apply(lambda text: ''.join(text.to_string(index=False))).reset_index()

# %% [markdown]
# # PLZ let me know how to remove the \n from my Neighbourhood    THANKS

# %%
df
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# 30       M3K        North York
# 31       M3L        North York
# 32       M3M        North York
# 33       M3N        North York
# 34       M4A        North York
# 35       M4B         East York
# 36       M4C         East York
# 37       M4E      East Toronto
# 38       M4G         East York
# 39       M4H         East York
# 40       M4J         East York
# 41       M4K      East Toronto
# 42       M4L      East Toronto
# 43       M4M      East Toronto
# 44       M4N   Central Toronto
# 45       M4P   Central Toronto
# 46       M4R   Central Toronto
# 47       M4S   Central Toronto
# 48       M4T   Central Toronto
# 49       M4V   Central Toronto
# 50       M4W  Downtown Toronto
# 51       M4X  Downtown Toronto
# 52       M4Y  Downtown Toronto
# 53       M5A  Downtown Toronto
# 54       M5B  Downtown Toronto
# 55       M5C  Downtown Toronto
# 56       M5E  Downtown Toronto
# 57       M5G  Downtown Toronto
# 58       M5H  Downtown Toronto
# 59       M5J  Downtown Toronto
# 60       M5K  Downtown Toronto
# 61       M5L  Downtown Toronto
# 62       M5M        North York
# 63       M5N   Central Toronto
# 64       M5P   Central Toronto
# 65       M5R   Central Toronto
# 66       M5S  Downtown Toronto
# 67       M5T  Downtown Toronto
# 68       M5V  Downtown Toronto
# 69       M5W  Downtown Toronto
# 70       M5X  Downtown Toronto
# 71       M6A        North York
# 72       M6B        North York
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7R       Mississauga
# 86       M7Y      East Toronto
# 87       M8V         Etobicoke
# 88       M8W         Etobicoke
# 89       M8X         Etobicoke
# 90       M8Y         Etobicoke
# 91       M8Z         Etobicoke
# 92       M9A         Etobicoke
# 93       M9B         Etobicoke
# 94       M9C         Etobicoke
# 95       M9L        North York
# 96       M9M        North York
# 97       M9N              York
# 98       M9P         Etobicoke
# 99       M9R         Etobicoke
# 100      M9V         Etobicoke
# 101      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                   Rouge\n, Malvern\n
# 1    Highland Creek\n,     Rouge Hill\n,     Port U...
# 2            Guildwood\n, Morningside\n,   West Hill\n
# 3                                             Woburn\n
# 4                                          Cedarbrae\n
# 5                                Scarborough Village\n
# 6    East Birchmount Park\n,              Ionview\n...
# 7             Clairlea\n, Golden Mile\n,    Oakridge\n
# 8    Cliffcrest\n,                Cliffside\n, Scar...
# 9                      Birch Cliff\n, Cliffside West\n
# 10   Dorset Park\n, Scarborough Town Centre\n,     ...
# 11                              Maryvale\n,  Wexford\n
# 12                                         Agincourt\n
# 13   Clarks Corners\n,       Sullivan\n,  Tam O'Sha...
# 14   Agincourt North\n, L'Amoreaux East\n,        M...
# 15                L'Amoreaux West\n,    Steeles West\n
# 16                                       Upper Rouge\n
# 17                                 Hillcrest Village\n
# 18              Fairview\n, Henry Farm\n,     Oriole\n
# 19                                   Bayview Village\n
# 20                      Silver Hills\n,   York Mills\n
# 21                        Newtonbrook\n,  Willowdale\n
# 22                                  Willowdale South\n
# 23                                   York Mills West\n
# 24                                   Willowdale West\n
# 25                                         Parkwoods\n
# 26                                   Don Mills North\n
# 27                Flemingdon Park\n, Don Mills South\n
# 28   Bathurst Manor\n, Downsview North\n,  Wilson H...
# 29                 Northwood Park\n, York University\n
# 30                     CFB Toronto\n, Downsview East\n
# 31                                    Downsview West\n
# 32                                 Downsview Central\n
# 33                               Downsview Northwest\n
# 34                                  Victoria Village\n
# 35              Woodbine Gardens\n,    Parkview Hill\n
# 36                                  Woodbine Heights\n
# 37                                       The Beaches\n
# 38                                           Leaside\n
# 39                                  Thorncliffe Park\n
# 40                                      East Toronto\n
# 41            The Danforth West\n,         Riverdale\n
# 42              The Beaches West\n,     India Bazaar\n
# 43                                   Studio District\n
# 44                                     Lawrence Park\n
# 45                                  Davisville North\n
# 46                                North Toronto West\n
# 47                                        Davisville\n
# 48                     Moore Park\n, Summerhill East\n
# 49   Deer Park\n,  Forest Hill SE\n,       Rathnell...
# 50                                          Rosedale\n
# 51                     Cabbagetown\n, St. James Town\n
# 52                              Church and Wellesley\n
# 53                      Harbourfront\n,  Regent Park\n
# 54                        Ryerson\n, Garden District\n
# 55                                    St. James Town\n
# 56                                       Berczy Park\n
# 57                                Central Bay Street\n
# 58                  Adelaide\n,     King\n, Richmond\n
# 59   Harbourfront East\n,   Toronto Islands\n,     ...
# 60        Design Exchange\n, Toronto Dominion Centre\n
# 61                  Commerce Court\n, Victoria Hotel\n
# 62               Bedford Park\n, Lawrence Manor East\n
# 63                                          Roselawn\n
# 64            Forest Hill North\n,  Forest Hill West\n
# 65       The Annex\n, North Midtown\n,     Yorkville\n
# 66                  Harbord\n, University of Toronto\n
# 67   Chinatown\n,       Grange Park\n, Kensington M...
# 68   CN Tower\n,     Bathurst Quay\n,    Island air...
# 69                   Stn A PO Boxes 25 The Esplanade\n
# 70      First Canadian Place\n,     Underground city\n
# 71              Lawrence Heights\n,   Lawrence Manor\n
# 72                                         Glencairn\n
# 73                                Humewood-Cedarvale\n
# 74                               Caledonia-Fairbanks\n
# 75                                          Christie\n
# 76          Dovercourt Village\n,           Dufferin\n
# 77                Little Portugal\n,         Trinity\n
# 78   Brockton\n, Exhibition Place\n, Parkdale Villa...
# 79   Maple Leaf Park\n,      North Park\n,     Upwo...
# 80   Del Ray\n,    Keelsdale\n, Mount Dennis\n,  Si...
# 81          The Junction North\n,          Runnymede\n
# 82                   High Park\n, The Junction South\n
# 83                          Parkdale\n, Roncesvalles\n
# 84                            Runnymede\n,   Swansea\n
# 85             Canada Post Gateway Processing Centre\n
# 86   Business reply mail Processing Centre969 Easte...
# 87   Humber Bay Shores\n,      Mimico South\n,     ...
# 88                          Alderwood\n, Long Branch\n
# 89   The Kingsway\n, Montgomery Road\n,  Old Mill N...
# 90   Humber Bay\n,         King's Mill Park\n, King...
# 91   Kingsway Park South West\n,                Mim...
# 92                                  Islington Avenue\n
# 93   Cloverdale\n,        Islington\n,     Martin G...
# 94   Bloordale Gardens\n,          Eringate\n,     ...
# 95                                     Humber Summit\n
# 96                                Emery\n, Humberlea\n
# 97                                            Weston\n
# 98                                         Westmount\n
# 99   Kingsview Village\n, Martin Grove Gardens\n,  ...
# 100  Albion Gardens\n, Beaumond Heights\n,       Hu...
# 101                                        Northwest\n

# %%
df.shape
# Out:
# (102, 3)

# %% [markdown]
# save this file to a new csv so i ca use in later assisment
# index=False avoid to creat new cololum

# %%
df.to_csv('firstpart.csv', encoding='utf-8',index=False)
